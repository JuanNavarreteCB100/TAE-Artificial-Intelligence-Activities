# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-z9ap8uml
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-z9ap8uml
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=3b011660c5ce19c50948bef4a5154f57324312c77e120142eb136542506a3433
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6z_vq44_/wheels/33/99/c5/794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10


# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
    nn.Conv1d(in_channels=1,  out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding=0),
    nn.ReLU(),
    nn.Flatten(),
    nn.Linear(60, 10)
)

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.910459, training error 77.12, validation loss 1.938549, validation error 78.30
# Epoch     1, training loss 1.425069, training error 57.45, validation loss 1.443145, validation error 58.60
# Epoch     2, training loss 1.316725, training error 52.15, validation loss 1.337546, validation error 55.90
# Epoch     3, training loss 1.266723, training error 50.28, validation loss 1.297144, validation error 52.80
# Epoch     4, training loss 1.206100, training error 48.35, validation loss 1.212831, validation error 50.60
# Epoch     5, training loss 1.125412, training error 45.53, validation loss 1.144123, validation error 47.40
# Epoch     6, training loss 1.134791, training error 47.95, validation loss 1.168273, validation error 50.30
# Epoch     7, training loss 1.010123, training error 41.28, validation loss 1.048936, validation error 44.80
# Epoch     8, training loss 0.928579, training error 37.30, validation loss 0.959014, validation error 40.00
# Epoch     9, training loss 0.873273, training error 34.10, validation loss 0.933938, validation error 38.00
# Epoch    10, training loss 0.770478, training error 31.25, validation loss 0.820728, validation error 33.70
# Epoch    11, training loss 0.700613, training error 28.30, validation loss 0.746920, validation error 30.80
# Epoch    12, training loss 0.648874, training error 25.53, validation loss 0.705598, validation error 27.60
# Epoch    13, training loss 0.597940, training error 23.15, validation loss 0.672816, validation error 26.40
# Epoch    14, training loss 0.616991, training error 24.50, validation loss 0.676644, validation error 25.60
# Epoch    15, training loss 0.483272, training error 18.85, validation loss 0.582072, validation error 22.90
# Epoch    16, training loss 0.408823, training error 15.65, validation loss 0.498022, validation error 19.30
# Epoch    17, training loss 0.413122, training error 16.35, validation loss 0.496192, validation error 19.60
# Epoch    18, training loss 0.530440, training error 20.22, validation loss 0.640409, validation error 23.30
# Epoch    19, training loss 0.514023, training error 19.28, validation loss 0.625478, validation error 22.80
# Epoch    20, training loss 0.285634, training error 10.25, validation loss 0.399474, validation error 14.00
# Epoch    21, training loss 0.247369, training error 8.53, validation loss 0.386927, validation error 13.50
# Epoch    22, training loss 0.262402, training error 9.82, validation loss 0.418907, validation error 13.90
# Epoch    23, training loss 0.232264, training error 8.15, validation loss 0.356298, validation error 11.50
# Epoch    24, training loss 0.214028, training error 7.85, validation loss 0.379448, validation error 12.40
# Epoch    25, training loss 0.198255, training error 6.97, validation loss 0.366925, validation error 11.90
# Epoch    26, training loss 0.168744, training error 5.62, validation loss 0.346906, validation error 11.40
# Epoch    27, training loss 0.180211, training error 6.28, validation loss 0.370497, validation error 12.50
# Epoch    28, training loss 0.158965, training error 5.38, validation loss 0.351636, validation error 11.70
# Epoch    29, training loss 0.160115, training error 5.47, validation loss 0.359819, validation error 10.70
# Epoch    30, training loss 0.148891, training error 4.93, validation loss 0.353207, validation error 10.50
# Epoch    31, training loss 0.141287, training error 4.95, validation loss 0.349054, validation error 10.50
# Epoch    32, training loss 0.128036, training error 4.03, validation loss 0.339712, validation error 10.00
# Epoch    33, training loss 0.113960, training error 3.75, validation loss 0.335831, validation error 10.60
# Epoch    34, training loss 0.135259, training error 5.00, validation loss 0.367949, validation error 10.60
# Epoch    35, training loss 0.108846, training error 3.50, validation loss 0.325234, validation error 9.00
# Epoch    36, training loss 0.136060, training error 4.82, validation loss 0.350859, validation error 10.30
# Epoch    37, training loss 0.157961, training error 6.03, validation loss 0.407904, validation error 11.40
# Epoch    38, training loss 0.109135, training error 3.82, validation loss 0.341093, validation error 10.40
# Epoch    39, training loss 0.106161, training error 3.65, validation loss 0.321681, validation error 9.00
# Epoch    40, training loss 0.090092, training error 3.03, validation loss 0.349261, validation error 10.10
# Epoch    41, training loss 0.078360, training error 2.25, validation loss 0.326816, validation error 9.90
# Epoch    42, training loss 0.073263, training error 2.10, validation loss 0.338702, validation error 9.30
# Epoch    43, training loss 0.068831, training error 1.93, validation loss 0.325424, validation error 8.30
# Epoch    44, training loss 0.067292, training error 1.80, validation loss 0.326682, validation error 8.40
# Epoch    45, training loss 0.065113, training error 1.90, validation loss 0.329641, validation error 8.70
# Epoch    46, training loss 0.070148, training error 2.03, validation loss 0.341963, validation error 8.30
# Epoch    47, training loss 0.060228, training error 1.47, validation loss 0.335811, validation error 7.90
# Epoch    48, training loss 0.063973, training error 1.85, validation loss 0.347892, validation error 8.70
# Epoch    49, training loss 0.057622, training error 1.35, validation loss 0.346615, validation error 8.80
# Epoch    50, training loss 0.056739, training error 1.43, validation loss 0.359002, validation error 8.80
# Epoch    51, training loss 0.057384, training error 1.60, validation loss 0.355658, validation error 8.90
# Epoch    52, training loss 0.051816, training error 1.25, validation loss 0.340120, validation error 8.00
# Epoch    53, training loss 0.057785, training error 1.57, validation loss 0.355316, validation error 8.80
# Epoch    54, training loss 0.051044, training error 1.15, validation loss 0.346007, validation error 8.70
# Epoch    55, training loss 0.062276, training error 1.95, validation loss 0.357327, validation error 8.90
# Epoch    56, training loss 0.055648, training error 1.68, validation loss 0.362308, validation error 8.40
# Epoch    57, training loss 0.047098, training error 1.10, validation loss 0.347435, validation error 7.80
# Epoch    58, training loss 0.044954, training error 0.80, validation loss 0.348189, validation error 8.10
# Epoch    59, training loss 0.049329, training error 1.12, validation loss 0.361105, validation error 8.50
# Epoch    60, training loss 0.042852, training error 0.85, validation loss 0.356017, validation error 8.00
# Epoch    61, training loss 0.041553, training error 0.60, validation loss 0.359960, validation error 7.90
# Epoch    62, training loss 0.041106, training error 0.75, validation loss 0.355648, validation error 7.80
# Epoch    63, training loss 0.040292, training error 0.68, validation loss 0.361267, validation error 8.10
# Epoch    64, training loss 0.040598, training error 0.75, validation loss 0.370044, validation error 7.90
# Epoch    65, training loss 0.042450, training error 0.95, validation loss 0.373070, validation error 8.50
# Epoch    66, training loss 0.040428, training error 0.70, validation loss 0.365298, validation error 8.20
# Epoch    67, training loss 0.038312, training error 0.65, validation loss 0.372685, validation error 8.20
# Epoch    68, training loss 0.038034, training error 0.53, validation loss 0.368292, validation error 8.20
# Epoch    69, training loss 0.037975, training error 0.60, validation loss 0.368081, validation error 7.90
# Epoch    70, training loss 0.037706, training error 0.65, validation loss 0.373702, validation error 8.10
# Epoch    71, training loss 0.036250, training error 0.47, validation loss 0.370645, validation error 8.00
# Epoch    72, training loss 0.037101, training error 0.57, validation loss 0.376627, validation error 8.10
# Epoch    73, training loss 0.035918, training error 0.53, validation loss 0.379928, validation error 8.20
# Epoch    74, training loss 0.035709, training error 0.47, validation loss 0.378070, validation error 8.30
# Epoch    75, training loss 0.035845, training error 0.55, validation loss 0.375818, validation error 8.10
# Epoch    76, training loss 0.034841, training error 0.45, validation loss 0.377550, validation error 8.30
# Epoch    77, training loss 0.034879, training error 0.45, validation loss 0.384440, validation error 8.40
# Epoch    78, training loss 0.034743, training error 0.47, validation loss 0.385994, validation error 8.30
# Epoch    79, training loss 0.033174, training error 0.38, validation loss 0.376793, validation error 7.70
# Epoch    80, training loss 0.032723, training error 0.38, validation loss 0.379572, validation error 7.70
# Epoch    81, training loss 0.033115, training error 0.38, validation loss 0.383480, validation error 8.20
# Epoch    82, training loss 0.032482, training error 0.35, validation loss 0.383959, validation error 8.30
# Epoch    83, training loss 0.032743, training error 0.45, validation loss 0.390168, validation error 8.30
# Epoch    84, training loss 0.031730, training error 0.32, validation loss 0.382755, validation error 8.00
# Epoch    85, training loss 0.031811, training error 0.40, validation loss 0.387946, validation error 8.20
# Epoch    86, training loss 0.031806, training error 0.35, validation loss 0.384326, validation error 8.20
# Epoch    87, training loss 0.031288, training error 0.35, validation loss 0.384437, validation error 7.80
# Epoch    88, training loss 0.031452, training error 0.32, validation loss 0.384936, validation error 7.90
# Epoch    89, training loss 0.031243, training error 0.38, validation loss 0.385057, validation error 7.90
# Epoch    90, training loss 0.030746, training error 0.32, validation loss 0.389931, validation error 8.20
# Epoch    91, training loss 0.030502, training error 0.28, validation loss 0.386557, validation error 7.90
# Epoch    92, training loss 0.030793, training error 0.30, validation loss 0.388344, validation error 8.10
# Epoch    93, training loss 0.030147, training error 0.28, validation loss 0.388073, validation error 7.80
# Epoch    94, training loss 0.029974, training error 0.25, validation loss 0.389607, validation error 8.00
# Epoch    95, training loss 0.029962, training error 0.32, validation loss 0.389089, validation error 8.10
# Epoch    96, training loss 0.029723, training error 0.28, validation loss 0.390105, validation error 8.00
# Epoch    97, training loss 0.029599, training error 0.32, validation loss 0.389824, validation error 7.80
# Epoch    98, training loss 0.029677, training error 0.30, validation loss 0.390636, validation error 8.00
# Epoch    99, training loss 0.029338, training error 0.28, validation loss 0.393557, validation error 8.20
